# %% [markdown]
# # Notebook 15: Mini Assessment
# **Filename:** `15_Mini_Assessment.ipynb`
# **Topic:** Hands-on Conceptual & Coding Assessment (NumPy & Pandas)
#
# ---
#
# ## Section 1: Conceptual Questions
#
# ### Question 1
# **Explain the fundamental differences between a NumPy Array and a Python List.**
#
# *Write your answer here:*
# -
#
# ---
#
# ### Question 2
# **Explain Broadcasting in NumPy with a short written example.**
#
# *Write your answer here:*
# -
#
# ---
#
# ### Question 3
# **Explain the difference between a Pandas Series and a Pandas DataFrame.**
#
# *Write your answer here:*
# -
#
# ---
#
# ## Section 2: Coding Exercises
#
# Complete the code cells below according to instructions.

# %% [markdown]
# ### Exercise 1: NumPy Array Creation & Math
# 1. Create a 1D NumPy array containing integers from 10 to 50.
# 2. Reshape it into a 2D matrix with 5 rows.
# 3. Calculate statistical measures: `mean`, `std`, and `sum`.

# %%
import numpy as np

# TODO: Write your solution here

# %% [markdown]
# ### Exercise 2: Data Loading & Selection
# 1. Create a sample Pandas DataFrame with columns: `Emp_ID`, `Name`, `Department`, `Salary`, `Age`.
# 2. Filter rows where `Salary > 60000` AND `Age < 35` using boolean indexing.

# %%
import pandas as pd

# TODO: Write your solution here

# %% [markdown]
# ### Exercise 3: GroupBy & Aggregation
# 1. Using the DataFrame from Exercise 2, group data by `Department`.
# 2. Calculate the total salary sum and average age per department using `agg()`.

# %%
# TODO: Write your solution here
