# %%
import numpy as Bk
stackly = Bk.array([220000, 230000, 300000, 250000, 310000])
print(Bk.mean(stackly))
print(Bk.median(stackly))
# Out:
# 262000.0
# 250000.0

# %%
import pandas as ela
Stackly =
